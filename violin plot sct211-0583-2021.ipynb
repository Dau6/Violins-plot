# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data_y=[8.04,6.95,7.58,8.81,8.33,9.96,7.24,4.26,10.84,4.82, 5.68]
data_x=[10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0,4.0,12.0, 7.0,5.0]


fig, ax=plt.subplots()
ax.scatter(x=data_x, y=data_y, c="#E69F00")


#ax.set_xlabel("We should label the x-axis")
#ax.set_ylabel("We should label the y axis")
#ax.set_title("Some title")


plt.xlabel("We should label the x-axis")
plt.ylabel("We should label the y axis")
plt.title("Some title")

#plt.savefig("my_first_plot.png")
# Out:
# Text(0.5, 1.0, 'Some title')

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\dell\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# # log scales

# %%
# !pip install panda
# Out:
# Requirement already satisfied: panda in c:\users\dell\anaconda3\lib\site-packages (0.3.1)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\lib\site-packages (from panda) (63.4.1)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (from panda) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests->panda) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests->panda) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests->panda) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests->panda) (2022.9.14)

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (1.21.5)

# %%
 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = pd.read_csv('C://Users//DELL//Downloads//gapminder_with_codes.csv')

data_2007 = data[data["year"]==2007]

fig, ax=plt.subplots()
ax.scatter(x=data_2007['gdpPercap'], y=data_2007['lifeExp'], alpha=0.5)
ax.set_xlabel('GDP (USD) per capita')
ax.set_ylabel('life expectancy (years)')
# Out:
# Text(0, 0.5, 'life expectancy (years)')

# %% [markdown]
# # log scale

# %%
fig, ax=plt.subplots()

ax.scatter(x=data_2007['gdpPercap'], y=data_2007['lifeExp'], alpha=0.9)
ax.set_xscale("log")
ax.set_xlabel('GDP (USD) Per Capita')
ax.set_ylabel('Life expectancy (years)')
# Out:
# Text(0, 0.5, 'Life expectancy (years)')

# %% [markdown]
# # how do you make tickmarks and axis label larger

# %%
fig, ax=plt.subplots()
ax.scatter(x=data_2007['gdpPercap'], y=data_2007['lifeExp'], alpha=0.8)
ax.set_ylabel('Life expectancy (years)', fontsize=15)
ax.set_xlabel('GDP(USD) per Capita', fontsize = 15)

ax.tick_params(which='major', length=10)
#ax.tick_params(which ='minor', length=10)
#ax.tick_params(labelsize=15)
# Out:
# (array([-10000.,      0.,  10000.,  20000.,  30000.,  40000.,  50000.,
#          60000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ## violinplot

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\dell\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\dell\anaconda3\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\dell\anaconda3\lib\site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: scipy>=1.0 in c:\users\dell\anaconda3\lib\site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\dell\anaconda3\lib\site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import seaborn as sns

sns.set_theme()

# Create a random dataset across several variables
rs = np.random.default_rng(0)
n, p = 40, 8
d = rs.normal(0, 2, (n, p))
d += np.log(np.arange(1, p + 1)) * -5 + 10

# Show each distribution with both violins and points
sns.violinplot(data=d, palette="light:g", inner="points", orient="h")
# Out:
# <AxesSubplot:>

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\dell\anaconda3\lib\site-packages (1.17.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (9.2.0)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (1.21.5)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: python-dateutil in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: blinker>=1.0.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (1.5)
# Requirement already satisfied: tornado>=5.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: requests>=2.4 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: toml in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: watchdog in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (3.1.30)
# Requirement already satisfied: rich>=10.11.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (13.3.1)
# Requirement already satisfied: click>=7.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: altair>=3.2.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (4.11.3)
# Requirement already satisfied: packaging>=14.1 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (21.3)
# Requirement already satisfied: pympler>=0.9 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (1.4.4)
# Requirement already satisfied: cachetools>=4.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: tzlocal>=1.1 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (4.2)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: validators>=0.2 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (0.20.0)
# Requirement already satisfied: semver in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (2.13.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (4.3.0)
# Requirement already satisfied: jinja2 in c:\users\dell\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\dell\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (4.16.0)
# Requirement already satisfied: entrypoints in c:\users\dell\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: toolz in c:\users\dell\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.11.2)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from click>=7.0->streamlit) (0.4.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\dell\anaconda3\lib\site-packages (from gitpython!=3.1.19->streamlit) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in c:\users\dell\anaconda3\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\dell\anaconda3\lib\site-packages (from packaging>=14.1->streamlit) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas>=0.21.0->streamlit) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (3.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.1.0 in c:\users\dell\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit) (2.1.0)
# Requirement already satisfied: pygments<3.0.0,>=2.14.0 in c:\users\dell\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit) (2.14.0)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\dell\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\users\dell\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit) (2022.7)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\dell\anaconda3\lib\site-packages (from validators>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\dell\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\dell\anaconda3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\dell\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\dell\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (21.4.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dell\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.1.0->rich>=10.11.0->streamlit) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Creating a Violin Plot with Seaborn
# import seaborn as sns
# import matplotlib.pyplot as plt
# df = sns.load_dataset('tips')
#
# sns.violinplot(data=df, y='tip')
# plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

#df = sns.load_dataset('data_2007')


data = pd.read_csv('C://Users//DELL//Downloads//gapminder_with_codes.csv')

data_2007 = data[data["year"]==2007]

#data_2007

#fig, ax = plt.subplots()
sns.violinplot(x=data_2007['gdpPercap'])
#, y=data_2007['lifeExp'])
sns.violinplot(y=data_2007['lifeExp'])


#sns.violinplot(data=df, x=data_2007['gdpPercap'], y=data_2007['lifeExp'])
plt.show()

# %%
# Creating Multiple Violin Plots with Seaborn

import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset('tips')

sns.violinplot(data=df, x='day', y='tip')
plt.show()

# %%
# Adding Additional Variables to Seaborn Violin Plots with hue
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset('tips')

sns.violinplot(data=df, x='day', y='tip', hue='sex')
plt.show()
